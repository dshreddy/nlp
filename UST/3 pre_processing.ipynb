# %%
# %%bash
#
# pip install --upgrade pip
# pip install farm-haystack[colab,ocr,preprocessing,file-conversion,pdf]
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (23.1.2)
# Collecting farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]
#   Downloading farm_haystack-1.18.1-py3-none-any.whl (737 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.2/737.2 kB 11.3 MB/s eta 0:00:00
# Collecting boilerpy3 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading boilerpy3-1.0.6-py3-none-any.whl (22 kB)
# Collecting canals==0.2.2 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading canals-0.2.2-py3-none-any.whl (31 kB)
# Collecting events (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading Events-0.4.tar.gz (5.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (4.3.3)
# Collecting lazy-imports==0.3.1 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading lazy_imports-0.3.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (9.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (8.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.8.1)
# Collecting posthog (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading posthog-3.0.1-py2.py3-none-any.whl (37 kB)
# Collecting prompthub-py==4.0.0 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading prompthub_py-4.0.0-py3-none-any.whl (6.9 kB)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.10.11)
# Collecting quantulum3 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading quantulum3-0.9.0-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 78.9 MB/s eta 0:00:00
# Collecting rank-bm25 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2.27.1)
# Collecting requests-cache<1.0.0 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading requests_cache-0.9.8-py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 6.0 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.2.2)
# Collecting sseclient-py (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading sseclient_py-1.7.2-py2.py3-none-any.whl (8.4 kB)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (8.2.2)
# Collecting tiktoken>=0.3.2 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading tiktoken-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 61.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (4.65.0)
# Collecting transformers==4.30.1 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading transformers-4.30.1-py3-none-any.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 68.2 MB/s eta 0:00:00
# Collecting azure-ai-formrecognizer>=3.2.0b2 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading azure_ai_formrecognizer-3.3.0b1-py3-none-any.whl (299 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 299.9/299.9 kB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (4.11.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.4.3)
# Collecting python-docx (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 78.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting python-frontmatter (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading python_frontmatter-1.0.0-py3-none-any.whl (9.0 kB)
# Collecting python-magic (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading python_magic-0.4.27-py2.py3-none-any.whl (13 kB)
# Collecting tika (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading tika-2.6.0.tar.gz (27 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pymupdf>=1.18.16 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading PyMuPDF-1.22.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 47.2 MB/s eta 0:00:00
# Collecting pdf2image>1.14 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading pdf2image-1.16.3-py3-none-any.whl (11 kB)
# Collecting pytesseract>0.3.7 (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Collecting langdetect (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 65.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.8.1)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from prompthub-py==4.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (6.0)
# Collecting requests (from farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.12.2)
# Collecting huggingface-hub<1.0,>=0.14.1 (from transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.4 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading safetensors-0.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.0 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.23.0 (from azure-ai-formrecognizer>=3.2.0b2->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading azure_core-1.28.0-py3-none-any.whl (185 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.4/185.4 kB 21.8 MB/s eta 0:00:00
# Collecting msrest>=0.6.21 (from azure-ai-formrecognizer>=3.2.0b2->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading msrest-0.7.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 8.4 MB/s eta 0:00:00
# Collecting azure-common~=1.1 (from azure-ai-formrecognizer>=3.2.0b2->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from azure-ai-formrecognizer>=3.2.0b2->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2023.5.7)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (23.1.0)
# Collecting cattrs>=22.2 (from requests-cache<1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading cattrs-23.1.2-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.8/50.8 kB 6.2 MB/s eta 0:00:00
# Collecting url-normalize>=1.4 (from requests-cache<1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.1.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2.4.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (0.19.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.16.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (8.1.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2022.7.1)
# Collecting monotonic>=1.5 (from posthog->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Collecting backoff>=1.10.0 (from posthog->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from python-docx->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (4.9.3)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from quantulum3->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (6.0.5)
# Collecting num2words (from quantulum3->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading num2words-0.5.12-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.2/125.2 kB 16.4 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (67.7.2)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache<1.0.0->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.14.1->transformers==4.30.1->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (2023.6.0)
# Collecting isodate>=0.6.0 (from msrest>=0.6.21->azure-ai-formrecognizer>=3.2.0b2->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: requests-oauthlib>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from msrest>=0.6.21->azure-ai-formrecognizer>=3.2.0b2->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (1.3.1)
# Collecting docopt>=0.6.2 (from num2words->quantulum3->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing])
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-ai-formrecognizer>=3.2.0b2->farm-haystack[colab,file-conversion,ocr,pdf,preprocessing]) (3.2.2)
# Building wheels for collected packages: events, langdetect, python-docx, tika, docopt
#   Building wheel for events (setup.py): started
#   Building wheel for events (setup.py): finished with status 'done'
#   Created wheel for events: filename=Events-0.4-py3-none-any.whl size=6273 sha256=0ae5b203db0d5363d6abc645cfa73ee3f3fcbc71a2549a0f5bfed499aa823582
#   Stored in directory: /root/.cache/pip/wheels/1b/34/cf/445b39702c5a25aa8ceccf99429f5855726be49d43ce31ec03
#   Building wheel for langdetect (setup.py): started
#   Building wheel for langdetect (setup.py): finished with status 'done'
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993224 sha256=6e64bce249e8446080a5f0fe2c072a7ffa90db002ff37d1e2d8e2e9f54c8b4a5
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
#   Building wheel for python-docx (setup.py): started
#   Building wheel for python-docx (setup.py): finished with status 'done'
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184491 sha256=5bbb82d0b5cbed0db6d034bd0c059fb123b01f6cf1f27250bd5acdfcf88bdc58
#   Stored in directory: /root/.cache/pip/wheels/80/27/06/837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
#   Building wheel for tika (setup.py): started
#   Building wheel for tika (setup.py): finished with status 'done'
#   Created wheel for tika: filename=tika-2.6.0-py3-none-any.whl size=32625 sha256=06fc350ef1739ed475906084bb553e76cec2ea29df8ee980e189724561c6f2f3
#   Stored in directory: /root/.cache/pip/wheels/5f/71/c7/b757709531121b1700cffda5b6b0d4aad095fb507ec84316d0
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=345269efecd218f3251f24489a4a5ecb3143e96c5cde44e32cbddc95f9e86a7a
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built events langdetect python-docx tika docopt
# Installing collected packages: tokenizers, sseclient-py, safetensors, monotonic, events, docopt, azure-common, url-normalize, requests, rank-bm25, python-magic, python-frontmatter, python-docx, pytesseract, pymupdf, pdf2image, num2words, lazy-imports, langdetect, isodate, cattrs, canals, boilerpy3, backoff, tiktoken, tika, requests-cache, prompthub-py, posthog, huggingface-hub, azure-core, transformers, quantulum3, msrest, farm-haystack, azure-ai-formrecognizer
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Uninstalling requests-2.27.1:
#       Successfully uninstalled requests-2.27.1
# Successfully installed azure-ai-formrecognizer-3.3.0b1 azure-common-1.1.28 azure-core-1.28.0 backoff-2.2.1 boilerpy3-1.0.6 canals-0.2.2 cattrs-23.1.2 docopt-0.6.2 events-0.4 farm-haystack-1.18.1 huggingface-hub-0.16.4 isodate-0.6.1 langdetect-1.0.9 lazy-imports-0.3.1 monotonic-1.6 msrest-0.7.1 num2words-0.5.12 pdf2image-1.16.3 posthog-3.0.1 prompthub-py-4.0.0 pymupdf-1.22.5 pytesseract-0.3.10 python-docx-0.8.11 python-frontmatter-1.0.0 python-magic-0.4.27 quantulum3-0.9.0 rank-bm25-0.2.2 requests-2.31.0 requests-cache-0.9.8 safetensors-0.3.1 sseclient-py-1.7.2 tika-2.6.0 tiktoken-0.4.0 tokenizers-0.13.3 transformers-4.30.1 url-normalize-1.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.27.1, but you have requests 2.31.0 which is incompatible.

# %%
#Haystack expects document corpus to be a list of documents in dictionary format
#each document has 2 main parts content & meta
# corpus = [ { 'content':"Document 1 content", 'meta':{'name':"Document 1 name",..} } ,...]

# %%
# Downloading the documents

from haystack.utils import fetch_archive_from_http
# This fetches some sample files to work with
doc_dir = "data/tutorial8"
s3_url = "https://s3.eu-central-1.amazonaws.com/deepset.ai-farm-qa/datasets/documents/preprocessing_tutorial8.zip"
fetch_archive_from_http(url=s3_url, output_dir=doc_dir)
# Out:
# True

# %%
from haystack.nodes import TextConverter, PDFToTextConverter, DocxToTextConverter, PreProcessor

converter = TextConverter(remove_numeric_tables=True, valid_languages=["en"])
doc_txt = converter.convert(file_path="data/tutorial8/classics.txt", meta=None)[0]

converter = PDFToTextConverter(remove_numeric_tables=True, valid_languages=["en"])
doc_pdf = converter.convert(file_path="data/tutorial8/bert.pdf", meta=None)[0]

converter = DocxToTextConverter(remove_numeric_tables=False, valid_languages=["en"])
doc_docx = converter.convert(file_path="data/tutorial8/heavy_metal.docx", meta=None)[0]

doc_txt
# Out:
# <Document: {'content': 'Classics or classical studies is the study of classical antiquity, and in the Western world traditionally refers to the study of Classical Greek and Roman literature in their original languages of Ancient Greek and Latin, respectively. It may also include Greco-Roman philosophy, history, and archaeology as secondary subjects.\n\nIn Western civilization, the study of the Greek and Roman classics was traditionally considered to be the foundation of the humanities, and study of classics has therefore traditionally been the cornerstone of a typical elite European education.\n\nEtymology\n\nThe word classics is derived from the Latin adjective classicus, meaning "belonging to the highest class of citizens." The word was originally used to describe the members of the highest class in ancient Rome. By the 2nd century AD the word was used in literary criticism to describe writers of the highest quality.[1] For example, Aulus Gellius, in his Attic Nights, contrasts "classicus" and "proletarius" writers.[2] By the 6th century AD, the word had acquired a second meaning, referring to pupils at a school.[1] Thus, the two modern meanings of the word, referring both to literature considered to be of the highest quality, and to the standard texts used as part of a curriculum, both derive from Roman use.[1]\nHistory\nMiddle Ages\nPhotograph of a bronze bust of a man. It rests on a stone plinth, on which the words "Gaius Valerius Catullus 87 AC–54 AC" are written.\nThe Roman poet Catullus was virtually unknown during the medieval period, in contrast to his modern popularity.\n\nIn the Middle Ages, classics and education were tightly intertwined; according to Jan Ziolkowski, there is no era in history in which the link was tighter.[3] Medieval education taught students to imitate earlier classical models,[4] and Latin continued to be the language of scholarship and culture, despite the increasing difference between literary Latin and the vernacular languages of Europe during the period.[4]\n\nWhile Latin was hugely influential, however, Greek was barely studied, and Greek literature survived almost solely in Latin translation.[5] The works of even major Greek authors such as Hesiod, whose names continued to be known by educated Europeans, were unavailable in the Middle Ages.[5] In the thirteenth century, the English philosopher Roger Bacon wrote that "there are not four men in Latin Christendom who are acquainted with the Greek, Hebrew, and Arabic grammars."[6]\n\nAlong with the unavailability of Greek authors, there were other differences between the classical canon known today and the works valued in the Middle Ages. Catullus, for instance, was almost entirely unknown in the medieval period.[5] The popularity of different authors also waxed and waned throughout the period: Lucretius, popular during the Carolingian period, was barely read in the twelfth century, while for Quintilian the reverse is true.[5]\nRenaissance\n\nThe Renaissance led to the increasing study of both ancient literature and ancient history,[7] as well as a revival of classical styles of Latin.[8] From the 14th century, first in Italy and then increasingly across Europe, Renaissance Humanism, an intellectual movement that "advocated the study and imitation of classical antiquity",[7] developed. Humanism saw a reform in education in Europe, introducing a wider range of Latin authors as well as bringing back the study of Greek language and literature to Western Europe.[8] This reintroduction was initiated by Petrarch (1304–1374) and Boccaccio (1313–1375) who commissioned a Calabrian scholar to translate the Homeric poems.[9] This humanist educational reform spread from Italy, in Catholic countries as it was adopted by the Jesuits, and in countries that became Protestant such as England, Germany, and the Low Countries, in order to ensure that future clerics were able to study the New Testament in the original language.[10]\nNeoclassicism\n\nThe late 17t ...

# %%
from haystack.utils import convert_files_to_docs
all_docs = convert_files_to_docs(dir_path=doc_dir)
