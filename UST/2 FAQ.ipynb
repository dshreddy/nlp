# %%
#Installing the required modules

# %%bash

pip install --upgrade pip
pip install farm-haystack[colab,inference]
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (23.1.2)
# Requirement already satisfied: farm-haystack[colab,inference] in /usr/local/lib/python3.10/dist-packages (1.18.1)
# Requirement already satisfied: boilerpy3 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (1.0.6)
# Requirement already satisfied: canals==0.2.2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.2.2)
# Requirement already satisfied: events in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.4)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (4.3.3)
# Requirement already satisfied: lazy-imports==0.3.1 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.3.1)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (9.1.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (3.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (1.5.3)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (8.4.0)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (3.8.1)
# Requirement already satisfied: posthog in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (3.0.1)
# Requirement already satisfied: prompthub-py==4.0.0 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (4.0.0)
# Requirement already satisfied: pydantic<2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (1.10.11)
# Requirement already satisfied: quantulum3 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.9.0)
# Requirement already satisfied: rank-bm25 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (2.31.0)
# Requirement already satisfied: requests-cache<1.0.0 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.9.8)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (1.2.2)
# Requirement already satisfied: sseclient-py in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (1.7.2)
# Requirement already satisfied: tenacity in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (8.2.2)
# Requirement already satisfied: tiktoken>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.4.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (4.65.0)
# Requirement already satisfied: transformers==4.30.1 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (4.30.1)
# Requirement already satisfied: huggingface-hub>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (0.16.4)
# Requirement already satisfied: sentence-transformers>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from farm-haystack[colab,inference]) (2.2.2)
# Requirement already satisfied: pyyaml<7.0,>=6.0 in /usr/local/lib/python3.10/dist-packages (from prompthub-py==4.0.0->farm-haystack[colab,inference]) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (3.12.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (2022.10.31)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (0.3.1)
# Requirement already satisfied: torch!=1.12.0,>=1.9 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (2.0.1+cu118)
# Requirement already satisfied: accelerate>=0.20.2 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (0.20.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (0.1.99)
# Requirement already satisfied: protobuf<=3.20.3 in /usr/local/lib/python3.10/dist-packages (from transformers==4.30.1->farm-haystack[colab,inference]) (3.20.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[colab,inference]) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.5.0->farm-haystack[colab,inference]) (4.7.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,inference]) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,inference]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,inference]) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->farm-haystack[colab,inference]) (2023.5.7)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,inference]) (1.4.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,inference]) (23.1.0)
# Requirement already satisfied: cattrs>=22.2 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,inference]) (23.1.2)
# Requirement already satisfied: url-normalize>=1.4 in /usr/local/lib/python3.10/dist-packages (from requests-cache<1.0.0->farm-haystack[colab,inference]) (1.4.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->farm-haystack[colab,inference]) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->farm-haystack[colab,inference]) (1.3.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->farm-haystack[colab,inference]) (3.1.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.0->farm-haystack[colab,inference]) (0.15.2+cu118)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=2.2.0->farm-haystack[colab,inference]) (3.8.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->farm-haystack[colab,inference]) (0.19.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack[colab,inference]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->farm-haystack[colab,inference]) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->farm-haystack[colab,inference]) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in /usr/local/lib/python3.10/dist-packages (from posthog->farm-haystack[colab,inference]) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from posthog->farm-haystack[colab,inference]) (2.2.1)
# Requirement already satisfied: inflect in /usr/local/lib/python3.10/dist-packages (from quantulum3->farm-haystack[colab,inference]) (6.0.5)
# Requirement already satisfied: num2words in /usr/local/lib/python3.10/dist-packages (from quantulum3->farm-haystack[colab,inference]) (0.5.12)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.2->transformers==4.30.1->farm-haystack[colab,inference]) (5.9.5)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from cattrs>=22.2->requests-cache<1.0.0->farm-haystack[colab,inference]) (1.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers==4.30.1->farm-haystack[colab,inference]) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers==4.30.1->farm-haystack[colab,inference]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch!=1.12.0,>=1.9->transformers==4.30.1->farm-haystack[colab,inference]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers==4.30.1->farm-haystack[colab,inference]) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch!=1.12.0,>=1.9->transformers==4.30.1->farm-haystack[colab,inference]) (16.0.6)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers>=2.2.0->farm-haystack[colab,inference]) (8.1.4)
# Requirement already satisfied: docopt>=0.6.2 in /usr/local/lib/python3.10/dist-packages (from num2words->quantulum3->farm-haystack[colab,inference]) (0.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch!=1.12.0,>=1.9->transformers==4.30.1->farm-haystack[colab,inference]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch!=1.12.0,>=1.9->transformers==4.30.1->farm-haystack[colab,inference]) (1.3.0)

# %%
#Since I saved the document corpus in a drive folder, I need to mount the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = "/content/drive/MyDrive/NLP/UST/small_faq_covid.csv"

# %%
from haystack.document_stores import InMemoryDocumentStore
document_store = InMemoryDocumentStore()

# %%
from haystack.nodes import EmbeddingRetriever

retriever = EmbeddingRetriever(
    document_store=document_store,
    embedding_model="sentence-transformers/all-MiniLM-L6-v2",
    use_gpu=True,
    scale_score=False,
)

# %%
import pandas as pd

# Get dataframe with columns "question", "answer" and some custom metadata
df = pd.read_csv(f"{file_path}")

# Minimal cleaning
df.fillna(value="", inplace=True)
df["question"] = df["question"].apply(lambda x: x.strip())
print(df.head())

# Create embeddings for our questions from the FAQs
# In contrast to most other search use cases, we don't create the embeddings here from the content of our documents,
# but rather from the additional text field "question" as we want to match "incoming question" <-> "stored question".
questions = list(df["question"].values)
df["embedding"] = retriever.embed_queries(queries=questions).tolist()
df = df.rename(columns={"question": "content"})

# Write documents to the DocumentStore
document_store.write_documents(df.to_dict(orient="records"))
# Out:
#                                             question  \
# 0                       What is a novel coronavirus?
# 1  Why is the disease being called coronavirus di...
# 2  Why might someone blame or avoid individuals a...
# 3  How can people help stop stigma related to COV...
# 4                   What is the source of the virus?
#
#                                               answer  \
# 0  A novel coronavirus is a new coronavirus that ...
# 1  On February 11, 2020 the World Health Organiza...
# 2  People in the U.S. may be worried or anxious a...
# 3  People can fight stigma and help, not hurt, ot...
# 4  Coronaviruses are a large family of viruses. S...
#
#                                          answer_html  \
# 0  <p>A novel coronavirus is a new coronavirus th...
# 1  <p>On February 11, 2020 the World Health Organ...
# 2  <p>People in the U.S. may be worried or anxiou...
# 3  <p>People can fight stigma and help, not hurt,...
# 4  <p>Coronaviruses are a large family of viruses...
#
#                                                 link  \
# 0  \nhttps://www.cdc.gov/coronavirus/2019-ncov/fa...
# 1  \nhttps://www.cdc.gov/coronavirus/2019-ncov/fa...
# 2  \nhttps://www.cdc.gov/coronavirus/2019-ncov/fa...
# 3  \nhttps://www.cdc.gov/coronavirus/2019-ncov/fa...
# 4  \nhttps://www.cdc.gov/coronavirus/2019-ncov/fa...
#
#                          name  \
# 0  Frequently Asked Questions
# 1  Frequently Asked Questions
# 2  Frequently Asked Questions
# 3  Frequently Asked Questions
# 4  Frequently Asked Questions
#
#                                             source  \
# 0  Center for Disease Control and Prevention (CDC)
# 1  Center for Disease Control and Prevention (CDC)
# 2  Center for Disease Control and Prevention (CDC)
# 3  Center for Disease Control and Prevention (CDC)
# 4  Center for Disease Control and Prevention (CDC)
#
#                           category country region city lang last_update
# 0  Coronavirus Disease 2019 Basics     USA               en  2020/03/17
# 1  Coronavirus Disease 2019 Basics     USA               en  2020/03/17
# 2  Coronavirus Disease 2019 Basics     USA               en  2020/03/17
# 3                   How It Spreads     USA               en  2020/03/17
# 4                   How It Spreads     USA               en  2020/03/17
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]

# %%
# Ask question & print answers
from haystack.pipelines import FAQPipeline
from haystack.utils import print_answers

pipe = FAQPipeline(retriever=retriever)
prediction = pipe.run(
    query="How is the virus spreading?",
    params={"Retriever": {"top_k": 1}}
    )
#print_answers(prediction, details="minimum")
print_answers(prediction, details="medium")
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 'Query: How is the virus spreading?'
# 'Answers:'
# [   {   'answer': 'This virus was first detected in Wuhan City, Hubei '
#                   'Province, China. The first infections were linked to a live '
#                   'animal market, but the virus is now spreading from '
#                   'person-to-person. It’s important to note that '
#                   'person-to-person spread can happen on a continuum. Some '
#                   'viruses are highly contagious (like measles), while other '
#                   'viruses are less so.\n'
#                   '\n'
#                   'The virus that causes COVID-19 seems to be spreading easily '
#                   'and sustainably in the community (“community spread”) in '
#                   'some affected geographic areas. Community spread means '
#                   'people have been infected with the virus in an area, '
#                   'including some who are not sure how or where they became '
#                   'infected.\n'
#                   '\n'
#                   'Learn what is known about the spread of newly emerged '
#                   'coronaviruses.',
#         'context': 'This virus was first detected in Wuhan City, Hubei '
#                    'Province, China. The first infections were linked to a '
#                    'live animal market, but the virus is now spreading from '
#                    'person-to-person. It’s important to note that '
#                    'person-to-person spread can happen on a continuum. Some '
#                    'viruses are highly contagious (like measles), while other '
#                    'viruses are less so.\n'
#                    '\n'
#                    'The virus that causes COVID-19 seems to be spreading '
#                    'easily and sustainably in the community (“community '
#                    'spread”) in some affected geographic areas. Community '
#                    'spread means people have been infected with the virus in '
#                    'an area, including some who are not sure how or where they '
#                    'became infected.\n'
#                    '\n'
#                    'Learn what is known about the spread of newly emerged '
#                    'coronaviruses.',
#         'score': 0.9358832836151123}]
